# %%
import random
# Hexadecimal to binary conversion
def hex2bin(s):
    mp = {'0' : "0000",
        '1' : "0001",
        '2' : "0010",
        '3' : "0011",
        '4' : "0100",
        '5' : "0101",
        '6' : "0110",
        '7' : "0111",
        '8' : "1000",
        '9' : "1001",
        'A' : "1010",
        'a' : "1010",
        'B' : "1011",
        'b' : "1011",
        'C' : "1100",
        'c' : "1100",
        'D' : "1101",
        'd' : "1101",
        'E' : "1110",
        'e' : "1110",
        'F' : "1111" ,
        'f' : "1111"}
    bin = ""
    for i in range(len(s)):
        bin = bin + mp[s[i]]
    return bin

# Binary to hexadecimal conversion
def bin2hex(s):
    mp = {"0000" : '0',
        "0001" : '1',
        "0010" : '2',
        "0011" : '3',
        "0100" : '4',
        "0101" : '5',
        "0110" : '6',
        "0111" : '7',
        "1000" : '8',
        "1001" : '9',
        "1010" : 'A',
        "1011" : 'B',
        "1100" : 'C',
        "1101" : 'D',
        "1110" : 'E',
        "1111" : 'F' }
    hex = ""
    for i in range(0,len(s),4):
        ch = ""
        ch = ch + s[i]
        ch = ch + s[i + 1]
        ch = ch + s[i + 2]
        ch = ch + s[i + 3]
        hex = hex + mp[ch]
        
    return hex

# Binary to decimal conversion
def bin2dec(binary):

    binary1 = binary
    decimal, i, n = 0, 0, 0
    while(binary != 0):
        dec = binary % 10
        decimal = decimal + dec * pow(2, i)
        binary = binary//10
        i += 1
    return decimal

# Decimal to binary conversion
def dec2bin(num):
    res = bin(num).replace("0b", "")
    if(len(res)%4 != 0):
        div = len(res) / 4
        div = int(div)
        counter =(4 * (div + 1)) - len(res)
        for i in range(0, counter):
            res = '0' + res
    return res

# Permute function to rearrange the bits
def permute(k, arr, n):
    permutation = ""
    for i in range(0, n):
        permutation = permutation + k[arr[i] - 1]
    return permutation

# shifting the bits towards left by nth shifts
def shift_left(k, nth_shifts):
    s = ""
    for i in range(nth_shifts):
        for j in range(1,len(k)):
            s = s + k[j]
        s = s + k[0]
        k = s
        s = ""
    return k

# calculating xor of two strings of binary number a and b
def xor(a, b):
    ans = ""
    for i in range(len(a)):
        if a[i] == b[i]:
            ans = ans + "0"
        else:
            ans = ans + "1"
    return ans

# Table of Position of 64 bits at initial level: Initial Permutation Table
initial_perm = [58, 50, 42, 34, 26, 18, 10, 2,
                60, 52, 44, 36, 28, 20, 12, 4,
                62, 54, 46, 38, 30, 22, 14, 6,
                64, 56, 48, 40, 32, 24, 16, 8,
                57, 49, 41, 33, 25, 17, 9, 1,
                59, 51, 43, 35, 27, 19, 11, 3,
                61, 53, 45, 37, 29, 21, 13, 5,
                63, 55, 47, 39, 31, 23, 15, 7]

# Expansion D-box Table
exp_d = [32, 1 , 2 , 3 , 4 , 5 , 4 , 5,
        6 , 7 , 8 , 9 , 8 , 9 , 10, 11,
        12, 13, 12, 13, 14, 15, 16, 17,
        16, 17, 18, 19, 20, 21, 20, 21,
        22, 23, 24, 25, 24, 25, 26, 27,
        28, 29, 28, 29, 30, 31, 32, 1 ]

# Straight Permutation Table
per = [ 16, 7, 20, 21,
        29, 12, 28, 17,
        1, 15, 23, 26,
        5, 18, 31, 10,
        2, 8, 24, 14,
        32, 27, 3, 9,
        19, 13, 30, 6,
        22, 11, 4, 25 ]

# S-box Table
sbox = [[[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
        [ 0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
        [ 4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
        [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13 ]],

        [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
            [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
            [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
        [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9 ]],

        [ [10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
        [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
        [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
            [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12 ]],

        [ [7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
        [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
        [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
            [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14] ],

        [ [2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
        [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
            [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
        [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3 ]],

        [ [12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
        [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
            [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
        [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13] ],

        [ [4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
        [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
            [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
            [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12] ],

        [ [13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
            [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
            [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
            [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11] ] ]

# Final Permutation Table
final_perm = [ 40, 8, 48, 16, 56, 24, 64, 32,
            39, 7, 47, 15, 55, 23, 63, 31,
            38, 6, 46, 14, 54, 22, 62, 30,
            37, 5, 45, 13, 53, 21, 61, 29,
            36, 4, 44, 12, 52, 20, 60, 28,
            35, 3, 43, 11, 51, 19, 59, 27,
            34, 2, 42, 10, 50, 18, 58, 26,
            33, 1, 41, 9, 49, 17, 57, 25 ]

# %%
#DES Implementation
def encrypt(pt, rkb, rk):
    pt = hex2bin(pt)
    # Initial Permutation
    pt = permute(pt, initial_perm, 64)
   
    #print("After initial permutation", bin2hex(pt))
    
    #Splitting
    left = pt[0:32]
    right = pt[32:64]
    for i in range(0, 16):
        # Expansion D-box: Expanding the 32 bits data into 48 bits
        right_expanded = permute(right, exp_d, 48)

        # XOR RoundKey[i] and right_expanded
        xor_x = xor(right_expanded, rkb[i])

        # S-boxex: substituting the value from s-box table by calculating row and column
        sbox_str = ""
        for j in range(0, 8):
            row = bin2dec(int(xor_x[j * 6] + xor_x[j * 6 + 5]))
            col = bin2dec(int(xor_x[j * 6 + 1] + xor_x[j * 6 + 2] + xor_x[j * 6 + 3] + xor_x[j * 6 + 4]))
            val = sbox[j][row][col]
            sbox_str = sbox_str + dec2bin(val)

        # Straight D-box: After substituting rearranging the bits
        sbox_str = permute(sbox_str, per, 32)

        # XOR left and sbox_str
        result = xor(left, sbox_str)
        left = result

        # Swapper
        if(i != 15):
            left, right = right, left
        #print("Round ", i + 1, " ", bin2hex(left), " ", bin2hex(right), " ", rk[i])

    # Combination
    combine = left + right

    # Final permutation: final rearranging of bits to get cipher text
    cipher_text = permute(combine, final_perm, 64)
    return cipher_text

def key_gen(key):
    # Key generation
    # --hex to binary
    key = hex2bin(key)

    # --parity bit drop table
    keyp = [57, 49, 41, 33, 25, 17, 9,
            1, 58, 50, 42, 34, 26, 18,
            10, 2, 59, 51, 43, 35, 27,
            19, 11, 3, 60, 52, 44, 36,
            63, 55, 47, 39, 31, 23, 15,
            7, 62, 54, 46, 38, 30, 22,
            14, 6, 61, 53, 45, 37, 29,
            21, 13, 5, 28, 20, 12, 4 ]

    # getting 56 bit key from 64 bit using the parity bits
    key = permute(key, keyp, 56)

    # Number of bit shifts
    shift_table = [1, 1, 2, 2,
                    2, 2, 2, 2,
                    1, 2, 2, 2,
                    2, 2, 2, 1 ]

    # Key- Compression Table : Compression of key from 56 bits to 48 bits
    key_comp = [14, 17, 11, 24, 1, 5,
                3, 28, 15, 6, 21, 10,
                23, 19, 12, 4, 26, 8,
                16, 7, 27, 20, 13, 2,
                41, 52, 31, 37, 47, 55,
                30, 40, 51, 45, 33, 48,
                44, 49, 39, 56, 34, 53,
                46, 42, 50, 36, 29, 32 ]

    # Splitting
    left = key[0:28] # rkb for RoundKeys in binary
    right = key[28:56] # rk for RoundKeys in hexadecimal

    rkb = []
    rk = []
    for i in range(0, 16):
        # Shifting the bits by nth shifts by checking from shift table
        left = shift_left(left, shift_table[i])
        right = shift_left(right, shift_table[i])

        # Combination of left and right string
        combine_str = left + right

        # Compression of key from 56 to 48 bits
        round_key = permute(combine_str, key_comp, 48)

        rkb.append(round_key)
        rk.append(bin2hex(round_key))
    return rkb, rk

pt = "123456ABCD132536"
key = "AABB09182736CCDD"

print("Encryption")
rkb,rk=key_gen(key)
cipher_text = bin2hex(encrypt(pt, rkb, rk))
print("Cipher Text : ",cipher_text)

print("Decryption")
rkb_rev = rkb[::-1]
rk_rev = rk[::-1]
text = bin2hex(encrypt(cipher_text, rkb_rev, rk_rev))
print("Plain Text : ",text)
# Out:
# Encryption
# Cipher Text :  C0B7A8D05F3A829C
# Decryption
# Plain Text :  123456ABCD132536

# %%
#DES Implementation with 128 bit key 

def key_gen128(key):
    # Key generation
    # --hex to binary
    key = hex2bin(key)
    keyL= key[0:63]
    keyR=key[64:]
    
    # --parity bit drop table
    keyp = [57, 49, 41, 33, 25, 17, 9,
            1, 58, 50, 42, 34, 26, 18,
            10, 2, 59, 51, 43, 35, 27,
            19, 11, 3, 60, 52, 44, 36,
            63, 55, 47, 39, 31, 23, 15,
            7, 62, 54, 46, 38, 30, 22,
            14, 6, 61, 53, 45, 37, 29,
            21, 13, 5, 28, 20, 12, 4 ]

    # getting 56 bit key from 64 bit using the parity bits
    keyL = permute(keyL, keyp, 56)
    keyR = permute(keyR, keyp, 56)

    # Number of bit shifts
    shift_table = [1, 1, 2, 2,
                    2, 2, 2, 2,
                    1, 2, 2, 2,
                    2, 2, 2, 1 ]

    # Key- Compression Table : Compression of key from 56 bits to 48 bits
    key_comp = [14, 17, 11, 24, 1, 5,
                3, 28, 15, 6, 21, 10,
                23, 19, 12, 4, 26, 8,
                16, 7, 27, 20, 13, 2,
                41, 52, 31, 37, 47, 55,
                30, 40, 51, 45, 33, 48,
                44, 49, 39, 56, 34, 53,
                46, 42, 50, 36, 29, 32 ]
    
    #random.shuffle([keyL])
    #random.shuffle([keyR])
    #left=keyL[0:27]
    #right=keyR[28:]
    # Splitting
    left = random.sample(keyL, 28) 
    right = random.sample(keyR, 28) 
    
    # rkb for RoundKeys in binary
    # rk for RoundKeys in hexadecimal
    rkb = []
    rk = []
    for i in range(0, 16):
        # Shifting the bits by nth shifts by checking from shift table
        left = shift_left(left, shift_table[i])
        right = shift_left(right, shift_table[i])

        # Combination of left and right string
        combine_str = left + right

        # Compression of key from 56 to 48 bits
        round_key = permute(combine_str, key_comp, 48)

        rkb.append(round_key)
        rk.append(bin2hex(round_key))
    return rkb, rk

pt = "123456ABCD132536"
key = "AABB09182736CCDDAABB09182736CCDD"
#pt="345678ABecEFabcE"
print("Encryption")
rkb,rk=key_gen128(key)
cipher_text = bin2hex(encrypt(pt, rkb, rk))
print("Cipher Text : ",cipher_text)

print("Decryption")
rkb_rev = rkb[::-1]
rk_rev = rk[::-1]
text = bin2hex(encrypt(cipher_text, rkb_rev, rk_rev))
print("Plain Text : ",text)
# Out:
# Encryption
# Cipher Text :  58B5BC957B268E57
# Decryption
# Plain Text :  123456ABCD132536

# %%
#calculating cipher text using modified des
def cipher_text1(plain,key):
    cipher_b=[]
    cipher_hex=[]
    for i in plain:
        rkb,rk=key_gen128(key)
        cipher_text = bin2hex(encrypt(i, rkb, rk))
        cipher_textb = encrypt(i, rkb, rk)
        print(cipher_text)
        cipher_hex.append(cipher_text)
        cipher_b.append(cipher_textb)
        
        rkb_rev = rkb[::-1]
        rk_rev = rk[::-1]
        text = bin2hex(encrypt(cipher_text, rkb_rev, rk_rev))
        
    return cipher_b,cipher_hex

# %%
#calculating cipher text using des
def cipher_text2(plain,key):
    cipher_b=[]
    cipher_hex=[]
    for i in plain:
        rkb,rk=key_gen(key)
        cipher_text = bin2hex(encrypt(i, rkb, rk))
        cipher_textb = encrypt(i, rkb, rk)
        print(cipher_text)
        cipher_hex.append(cipher_text)
        cipher_b.append(cipher_textb)
        
        rkb_rev = rkb[::-1]
        rk_rev = rk[::-1]
        text = bin2hex(encrypt(cipher_text, rkb_rev, rk_rev))
        #print(text==i)
    return cipher_b,cipher_hex

# %%
def compare_strings(a, b):
    count = 0 # A counter to keep track of same characters
    for i in range(len(a)):
        if a[i] == b[i]:
            count += 1 # Updating the counter when characters are same at an index

    #print("Number of different Characters:", len(a)- count)
    av=(len(a)-count)*100.0/len(a)
    #print('Avalanche effect', av)
    
    return av

# %%
# make arrays of hex input and binary input
def plain_text(pt):
    plain=[]
    plain_b=[]
    for i in range(0,10):
        x=str(i)+ pt
        plain.append(x)
        plain_b.append(hex2bin(x))
        #print(x)

    for i in range(65,71):
        x=chr(i)+ pt
        plain.append(x)
        plain_b.append(hex2bin(x))
        #print(x)
    return plain,plain_b

# %%
#find avalanche effect in des algo using hex input
key = "AABB09182736CCDD"
pt='23456ABCD132536'
plain, plain_b=plain_text(pt)
cipher_b2,cipher_hex2 = cipher_text2(plain,key)
# Out:
# 22AF081E9DD9EF8A
# C0B7A8D05F3A829C
# 0AACD715FB166FD6
# F8F454B94CCAF8B6
# 29D266182FBC18B4
# 6B05C199BD5C7573
# 4FEB2A18FA27CF12
# 350918AEC59D12A6
# 363F37146018A07D
# 89F6EB4779DDA0ED
# AC4D4EE301097354
# CB47ADA3691314B7
# 40D067F0595CC9D7
# 003EABE4E5857F29
# 0763D2B4EC244147
# BF8899C661114B3E

# %%
#des
avalanche_hex2=[]
for i in range(1,len(plain)):
    #print('plain text change')
    #compare_strings(plain[0],plain[i])
    #print('cipher text change')
    avalanche_hex2.append(compare_strings(cipher_hex2[0],cipher_hex2[i]))
    #print("")

# %%
#des
avalanche_b2=[]
for i in range(1,len(plain_b)):
    #print('plain text change')
    #compare_strings(plain_b[0],plain_b[i])
    #print('cipher text change')
    avalanche_b2.append(compare_strings(cipher_b2[0],cipher_b2[i]))
    #print('')

# %%
s1=0
s2=0
for i in range(len(avalanche_hex2)):
    s1 =s1 + avalanche_hex2[i]
    s2 =s2 + avalanche_b2[i]
    
print('average avalanche effect in hex on first char in DES algo with hex input',s1/len(avalanche_hex2))
print('average avalanche effect in binary on first char in DES algo with hex input',s2/len(avalanche_hex2))
# Out:
# average avalanche effect in hex on first char in DES algo with hex input 93.33333333333333
# average avalanche effect in binary on first char in DES algo with hex input 50.729166666666664

# %%
#find avalanche effect in modified des algo with 128 bit key using hex input
key = "AABB09182736CCDD19BA9212CF26B472"
pt='23456ABCD132536'
plain, plain_b=plain_text(pt)
cipher_b,cipher_hex = cipher_text1(plain,key)
# Out:
# DCA0C6445EDA8737
# BF6A272C8C121547
# C1BB08099CF8C10B
# E39572D4496B2440
# 355F2BF9AD93A4C0
# F26A918AC7AEBAA1
# 33CAE6BEA54FE78C
# DC1BA7BA00818C39
# 8D8689B1A32A7438
# BFCC38783C3124B1
# 0CBF60C47BCE807C
# B74943199FEC6889
# EF3BC4870A03762E
# 3C29655AE5567467
# 2C5278AE4CA14F3D
# 0352774BE22C3A9B

# %%
#mdes
avalanche_hex1=[]
for i in range(1,len(plain)):
    #print('plain text change')
    #compare_strings(plain[0],plain[i])
    #print('cipher text change')
    avalanche_hex1.append(compare_strings(cipher_hex[0],cipher_hex[i]))
    #print("")

# %%
#mdes
avalanche_b1=[]
for i in range(1,len(plain_b)):
    #print('plain text change')
    #compare_strings(plain_b[0],plain_b[i])
    #print('cipher text change')
    avalanche_b1.append(compare_strings(cipher_b[0],cipher_b[i]))
    #print('')

# %%
s1=0
s2=0
for i in range(len(avalanche_hex1)):
    s1 =s1 + avalanche_hex1[i]
    s2 =s2 + avalanche_b1[i]
    
print('average avalanche effect in hex on first char in modified DES with hex input',s1/len(avalanche_hex1))
print('average avalanche effect in binary on first char in modified DES with hex input',s2/len(avalanche_hex1))
# Out:
# average avalanche effect in hex on first char in modified DES with hex input 92.08333333333333
# average avalanche effect in binary on first char in modified DES with hex input 53.125

# %%
def ASCIItoHEX(ascii):

    hexa = ""
    for i in range(len(ascii)):

        ch = ascii[i]
        in1 = ord(ch)
        
        part = hex(in1).lstrip("0x").rstrip("L")
        
        hexa += part
    return hexa

# %%
def text_input(text):
    plain_in=[]
    hex_in=[]
    bin_in=[]
    for i in range(48,58):
            x=chr(i)+text
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)
    for i in range(97,123):
            x=chr(i)+text
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)
 
    for i in range(65,91):
            x=chr(i)+text
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)

    return hex_in,plain_in,bin_in

# %%
# find avalanche effect in modified des algo using plain text input
#text = "HAVYzSE"
text='MBMUCSED'
key = "AABB09182736CCDD19BA9212CF26B472"
hex_in,plain_in,bin_in=text_input(text)
cipher_b,cipher_hex=cipher_text1(hex_in,key)
# Out:
# A115E304D97BDD37
# E0CE260AFCE7FACB
# 3BE233930BD6032B
# 1C212290B2EBDDE5
# 695F5366FF3C26BD
# CD44C2F6D0A018D4
# F8D50B7123320B41
# 7ED2C4691B3A5FD0
# AEE7543504005310
# E11B78AF3B81D1DA
# 337E4971DCE872BC
# 556E5C372E38C366
# C7474776B50BA6A7
# D1E05D20C12DE2E5
# F761330F14353F75
# A68B69003AA84586
# 3E785E0B0057A087
# D1E33406E892ECBA
# 0B14D4F6A16DCEA2
# B7ADCDBC4ED9AE4F
# 5C3CD9E496141D42
# 00C2B3788C78D603
# DFA7FBE08F1043C5
# FA344309D3F339E7
# 05F1F5AF6E1F2D3F
# 110C84E2A54E9C68
# D095F3A6306E03F1
# 4CD174932F000BB7
# CD04D3649E97A391
# 79948DC69B1383C6
# 324829C11199DBB7
# 209F85A7047D65DF
# DC495DAB4E3C3A27
# 8D44BB64BA330F30
# B7D3213875ED5BBE
# B23FF3D9842AC64F
# 4F77B040EE3F7E49
# 464F83626A138281
# AA8E4A6BE0928D42
# 003931A925542F40
# 7EBF361B4F57053A
# D90139E90970B6E8
# 92787C7A74E4938B
# 4E1CFA5650F32BB6
# 031ED7A49CE88917
# 857930290579D374
# 57E8956BA218275C
# D6B184BA1715C038
# 889E6309138FFE38
# E84E357969B184C6
# A882AFB68089068C
# ADEC1958F3270A14
# ...

# %%
avalanche_hex_plain1=[]
for i in range(1,len(plain_in)):
    print('plain text change')
    print("Number of different Characters:", 1)
    print('Avalanche effect', 100.0/8)
    print('cipher text change')
    avalanche_hex_plain1.append(compare_strings(cipher_hex[0],cipher_hex[i]))
    print("")
# Out:
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# Avalanche effect 12.5
# cipher text change
#
# plain text change
# Number of different Characters: 1
# ...

# %%
avalanche_bin_plain1=[]
for i in range(1,len(plain_in)):
    print('plain text change')
    compare_strings(bin_in[0],bin_in[i])
    print('cipher text change')
    avalanche_bin_plain1.append(compare_strings(cipher_b[0],cipher_b[i]))
    print("")
# Out:
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# plain text change
# cipher text change
#
# ...

# %%
#mdes
s1=0
s2=0
for i in range(len(avalanche_hex_plain1)):
    s1 =s1 + avalanche_hex_plain1[i]
    s2 =s2 + avalanche_bin_plain1[i]
    
print('average avalanche effect on first char in hex using modified des where input is plain text',s1/len(avalanche_hex_plain1))
print('average avalanche effect on first char in binary using modified des where input is plain text',s2/len(avalanche_hex_plain1))
# Out:
# average avalanche effect on first char in hex using modified des where input is plain text 92.41803278688525
# average avalanche effect on first char in binary using modified des where input is plain text 50.05122950819672

# %%
# find avalanche effect in des algo using plain text input
#text = "HAVYzSE"
text='MBMUCSED'
key = "AABB09182736CCDD"
hex_in,plain_in,bin_in=text_input(text)
cipher_b2,cipher_hex2=cipher_text2(hex_in,key)
# Out:
# DBF54840FC8DA173
# 7E3D58D89E911065
# B8F6957618D8492E
# 5B37C358A19BDF16
# 4B41F214B7238322
# 76BB3F9A18AAF251
# 12BDA1CD370562A8
# 0D9D71BF3B1BA335
# C034FBB048A24226
# 53B1D9CBE7C8F4CB
# 4E5B316251A91942
# 005A9DABB033236B
# DE10C9AB0FB04507
# A3B76F3138F3D20E
# 1F0440BA2C1644C8
# F6920D5871266044
# 288634AF02135A43
# 5CDEDDDBA007C167
# 228124EF506AA0C1
# BF8035B6E1A23AF7
# 7B04105414B75673
# 889507CFFCC46351
# 1710763F5205C3E6
# 42606919D5465FDF
# D802055F3F8F111D
# C54DDC3D6D27F41A
# 9BA4A706F86B555D
# 78102E2FC47194A1
# 1569D5A8EA2CAEB1
# 7001FA21D2A6790B
# 8D34393175AB0929
# 1F48B2CFD9DA074D
# CC20CE017D5276B7
# 95AE06A5B935CF70
# AE5D5B4EBD324480
# D9B02A30F4C23099
# 59EA3D539DC93F84
# 1D79078E5B32B064
# FE7D37B5D6CF8218
# F7364D1CC88C6B65
# DE03DBD1B090C72D
# D26845FE4F1535DF
# DADB7B3853D5E6FD
# 930DFF6FE92C2652
# B1831C00BE1CA6A8
# 902817BCDCA62507
# 1858A80E4EFC2ED3
# 0D27C0D5E649B9F5
# 2FF415517794C271
# 0430EF0F4C435086
# AAB5AC2E3840FAAA
# CA53898D16BD40C7
# ...

# %%
avalanche_hex_plain2=[]
for i in range(1,len(plain_in)):
    #print('plain text change')
    #print("Number of different Characters:", 1)
    #print('Avalanche effect', 100.0/8)
    #print('cipher text change')
    avalanche_hex_plain2.append(compare_strings(cipher_hex2[0],cipher_hex2[i]))
    #print("")

# %%
avalanche_bin_plain2=[]
for i in range(1,len(plain_in)):
    #print('plain text change')
    #compare_strings(bin_in[0],bin_in[i])
    #print('cipher text change')
    avalanche_bin_plain2.append(compare_strings(cipher_b2[0],cipher_b2[i]))
    #print("")

# %%
#des
s1=0
s2=0
for i in range(len(avalanche_hex_plain2)):
    s1 =s1 + avalanche_hex_plain2[i]
    s2 =s2 + avalanche_bin_plain2[i]
    
print('average avalanche effect on first char in hex using des algo where input is plain text',s1/len(avalanche_hex_plain2))
print('average avalanche effect on first char in binary using des algo where input is plain text',s2/len(avalanche_hex_plain2))
# Out:
# average avalanche effect on first char in hex using des algo where input is plain text 94.05737704918033
# average avalanche effect on first char in binary using des algo where input is plain text 48.79610655737705

# %%
#function to change last charcter of hex input
def plain_last(pt):
    plain=[]
    plain_b=[]
    for i in range(0,10):
        x= pt + str(i)
        plain.append(x)
        plain_b.append(hex2bin(x))
        #print(x)

    for i in range(65,71):
        x= pt+ chr(i)
        plain.append(x)
        plain_b.append(hex2bin(x))
        #print(x)
    return plain,plain_b

# %%
#find avalanche effect in modified des algo on last char using hex input
key = "AABB09182736CCDD19BA9212CF26B472"
pt='23456ABCD132536'
plainL, plainL_b=plain_last(pt)
cipherL_b,cipherL_hex = cipher_text1(plainL,key)
# Out:
# D0240D78B0E23C52
# 5EE223745720CEFC
# 48642180A5F01222
# 5B03C85C3D65DE2F
# BE83BBB9BA1EB312
# D5699F0CE66141C2
# 1008AB3ACD4D3236
# E501233421A9C83B
# 88889AF9926F9D9C
# 2AA55FED6FBFBE02
# 656895029BD6FFD2
# 30B53397BCA8339F
# 34A665A6AF92F27B
# FBFB6A4642BCAAE9
# 52AAADADD133F8FE
# 47311F61B625274C

# %%
#mdes
avalancheL_hex1=[]
for i in range(1,len(plainL)):
    #print('plain text change')
    #compare_strings(plainL[0],plainL[i])
    #print('cipher text change')
    avalancheL_hex1.append(compare_strings(cipherL_hex[0],cipherL_hex[i]))
    #print("")

# %%
#mdes
avalancheL_b1=[]
for i in range(1,len(plain_b)):
    #print('plain text change')
    #compare_strings(plainL_b[0],plainL_b[i])
    #print('cipher text change')
    avalancheL_b1.append(compare_strings(cipherL_b[0],cipherL_b[i]))
    #print('')

# %%
s1=0
s2=0
for i in range(len(avalancheL_hex1)):
    s1 =s1 + avalancheL_hex1[i]
    s2 =s2 + avalancheL_b1[i]
    
print('average avalanche effect in hex on last char in modified des algo using hex input',s1/len(avalancheL_hex1))
print('average avalanche effect in binary on last char in modified des algo using hex input',s2/len(avalancheL_hex1))
# Out:
# average avalanche effect in hex on last char in modified des algo using hex input 92.91666666666667
# average avalanche effect in binary on last char in modified des algo using hex input 47.291666666666664

# %%
#find avalanche effect in des algo on last char using hex input
key = "AABB09182736CCDD"
pt='23456ABCD132536'
plainL, plainL_b=plain_last(pt)
cipherL_b,cipherL_hex = cipher_text2(plainL,key)
# Out:
# 004390C982C8DB75
# 73D3827122D53245
# 51E896FF38AD3291
# 9C8051293983BFF5
# 57807F2F3E32837B
# 956C79F1FF73B103
# 9CB32C79183D2BDB
# 2B1161DC5C1C08B2
# C4E36CC460006EDD
# 07ED2AF62A52C1FF
# C2490D5EC178E1D3
# 116EE7ACCF782E88
# A36C8025263499FA
# AC47B4349CC5ACD0
# ED6721039F3BAD40
# 9AB298BEC589A25B

# %%
avalancheL_hex2=[]
for i in range(1,len(plainL)):
    #print('plain text change')
    #compare_strings(plainL[0],plainL[i])
    #print('cipher text change')
    avalancheL_hex2.append(compare_strings(cipherL_hex[0],cipherL_hex[i]))
    #print("")

# %%
avalancheL_b2=[]
for i in range(1,len(plain_b)):
    #print('plain text change')
    #compare_strings(plainL_b[0],plainL_b[i])
    #print('cipher text change')
    avalancheL_b2.append(compare_strings(cipherL_b[0],cipherL_b[i]))
    #print('')

# %%
s1=0
s2=0
for i in range(len(avalancheL_hex2)):
    s1 =s1 + avalancheL_hex2[i]
    s2 =s2 + avalancheL_b2[i]
    
print('average avalanche effect in hex on last char in des algo using hex input',s1/len(avalancheL_hex2))
print('average avalanche effect in binary on last char in des algo using hex input',s2/len(avalancheL_hex2))
# Out:
# average avalanche effect in hex on last char in des algo using hex input 91.66666666666667
# average avalanche effect in binary on last char in des algo using hex input 50.625

# %%
def text_inputL(text):
    plain_in=[]
    hex_in=[]
    bin_in=[]
    for i in range(48,58):
            x=text + chr(i)
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)
        
    for i in range(97,123):
            x=text+ chr(i)
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)
            
    for i in range(65,91):
            x=text+ chr(i)
            plain_in.append(x)
            b=ASCIItoHEX(x)
            hex_in.append(b)
            bin_in.append(b)
            
    return hex_in,plain_in,bin_in

# %%
#find avalanche effect in modified des algo on last char using plain text input
text = "HAVYzSE"
key = "AABB09182736CCDD19BA9212CF26B472"
hex_in,plain_in,bin_in=text_inputL(text)
cipher_b,cipher_hex=cipher_text1(hex_in,key)
# Out:
# 3E0F1BD258D5483D
# 6ABB2A112E265FC3
# 044CFC4A8D368243
# 24EEBC61F263AC7A
# 946BD955CC68C13F
# 176C8E1A3DA8E068
# 34F4212055787994
# E60A94837BF1B7BC
# F585906D374B4B79
# D6CA0CC0CA0CC3D7
# 5D801E1B30498D62
# 62AEDC3498CD325C
# 4EB9031E12DF9A40
# E3B2DE6B11FFF0CA
# 59387E42FB45E989
# 8B8A67C2B381FC75
# 301396ACDF2FC3EC
# 9D66D9AEC8A928AE
# B970D9C989FF062B
# 85CBAC64EDE88C7F
# 8FA6DCF0A1187BDE
# 13B9924CB008058C
# 0FFA42DFD3CFCD8F
# A09597882DB37BF2
# 16E233B635CB050B
# 521F8E32FA967DE9
# 0EE8BBAFD7A059FA
# E1C84142A05E297B
# 2A642DFB1F4CC6D4
# 8D5A12CF88B5FC1B
# 49F2217734B01238
# 0B5A544C5DDB662A
# 5F9189F4E94E1C58
# 8600B14ED86DC842
# 8142A56D07204542
# E8533060FF31A94E
# F2F4E5A77299C1AD
# 4D2E0B39F0962AD2
# C80CD9671FDD48C0
# CE6EAB3D0E0898D9
# D7214FE1E817BD19
# D40D9CEE2F588792
# B3A86A121D99369F
# 836E45D7CD36A03B
# 81D0F97363275DE1
# EE987AF62A922B67
# 9BE86263F3EA89EF
# 8362D9B37773E484
# A83D42094510516F
# 21064FE087CBF295
# 5F0E4D30F00B2675
# 559694564887FC80
# ...

# %%
avalanche_hex_plainL1=[]
for i in range(1,len(hex_in)):
    #print('plain text change')
    #print("Number of different Characters:", 1)
    #print('Avalanche effect', 100.0/8)
    #print('cipher text change')
    avalanche_hex_plainL1.append(compare_strings(cipher_hex[0],cipher_hex[i]))
    #print("")

# %%
avalanche_bin_plainL1=[]
for i in range(1,len(hex_in)):
    #print('plain text change')
    #compare_strings(bin_in[0],bin_in[i])
    #print('cipher text change')
    avalanche_bin_plainL1.append(compare_strings(cipher_b[0],cipher_b[i]))
    #print("")

# %%
s1=0
s2=0
for i in range(len(avalanche_bin_plainL1)):
    s1 =s1 + avalanche_hex_plainL1[i]
    s2 =s2 + avalanche_bin_plainL1[i]
    
print('average avalanche effect in hex on last char in modified des algo using text input',s1/len(avalanche_bin_plainL1))
print('average avalanche effect in binary on last char in modified des algo using text input',s2/len(avalanche_bin_plainL1))
# Out:
# average avalanche effect in hex on last char in modified des algo using text input 94.4672131147541
# average avalanche effect in binary on last char in modified des algo using text input 50.46106557377049

# %%
#find avalanche effect in des algo on last char using plain text input
text = "HAVYzSE"
key = "AABB09182736CCDD"
hex_in,plain_in,bin_in=text_inputL(text)
cipher_b,cipher_hex=cipher_text2(hex_in,key)
# Out:
# 10323701B7F1758F
# 099707CA69158B48
# 49748D74205304C6
# BB05DD0E5F9391D7
# C308C4092D692213
# 2B5C15095D464F2F
# F71796FB8D0340AD
# 4E8144D96482B16F
# 7D5953E31387A80D
# 34E966BB11B863C6
# 80447863C032C780
# ED066DEB56E4303A
# 2D19D0773B740884
# 0954703E829493D1
# D0A8E05B023DEA46
# E3594D44C511A3A5
# C71BEFF9C2BB6766
# 5E95AED209641043
# E0B70BA9593611A7
# 59E8A87672D1A133
# E0DA7EA89E4FBB7E
# 5EAF1B194F28D070
# 66FC45F256B7D160
# D5BC112C775B60BC
# FBFA0D52B233ED75
# 6687FE34924EE18C
# 8C59385BA9F2484B
# F3AF792F6C3F3AF7
# 3E035E8A86F4C1A8
# 4EE32918CB50F7BD
# 8D92F475D6C92BF5
# 9211F2A15A5B2798
# 71180D34E337168E
# 2FFAD5A0D898DF29
# E7F5C6A18CE4201E
# 2864E923BA4A1F9B
# 5D9090E9824ABF0B
# A9410CC63EE4929C
# 0EDB702A8307A981
# 3954825C9FF5BBF5
# 94DE4DFD39A4E00D
# D235FF61EBA465C5
# 0CA829031D540EEE
# 01F5498B283D9B45
# 61B9F17F951619A7
# E11824E053E639BA
# 6B5494727D149448
# 77C7AF66992C8FFD
# 9B782CFEC63B65C1
# 07DE1B46CD792261
# 21716AC269BDC4FA
# 9BBA147A1D2CB80F
# ...

# %%
avalanche_hex_plainL2=[]
for i in range(1,len(hex_in)):
    #print('plain text change')
    #print("Number of different Characters:", 1)
    #print('Avalanche effect', 100.0/8)
    #print('cipher text change')
    avalanche_hex_plainL2.append(compare_strings(cipher_hex[0],cipher_hex[i]))
    #print("")

# %%
avalanche_bin_plainL2=[]
for i in range(1,len(hex_in)):
    #print('plain text change')
    #compare_strings(bin_in[0],bin_in[i])
    #print('cipher text change')
    avalanche_bin_plainL2.append(compare_strings(cipher_b[0],cipher_b[i]))
    #print("")

# %%
s1=0
s2=0
for i in range(len(avalanche_bin_plainL2)):
    s1 =s1 + avalanche_hex_plainL2[i]
    s2 =s2 + avalanche_bin_plainL2[i]
    
print('average avalanche effect in hex on last char in des algo using text input',s1/len(avalanche_bin_plainL2))
print('average avalanche effect in binary on last char in des algo using text input',s2/len(avalanche_bin_plainL2))
# Out:
# average avalanche effect in hex on last char in des algo using text input 95.28688524590164
# average avalanche effect in binary on last char in des algo using text input 50.614754098360656
